# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('RF_Padded_File.csv')
# Out:
# /var/folders/41/rlmz0mh15dx9_qw9xxbv4mq00000gn/T/ipykernel_9820/3102805024.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('RF_Padded_NaNs.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Speed_MPH', 'ATP', 'BP_Hg', 'JF', 'FF',
#        'Src_Temperature', 'Src_Pressure', 'Src_WindSpeed', 'Src_Weather_Info',
#        'NR_HR', 'Age', 'Trait_Anxiety', 'Extraversion', 'Agreeableness',
#        'Conscientiousness', 'Neuroticism', 'Openness', 'Gender_Female',
#        'Gender_Male', 'Weekday', 'Weekend'],
#       dtype='object')

# %%
arr=df['Unnamed: 0'].values
arr2=[i for i in range(244713)]

# %%
dct={}
for i in range(len(arr2)):
    dct[arr2[i]]=arr[i]

# %%
dct
# Out:
# {0: 8903,
#  1: 8904,
#  2: 8905,
#  3: 8906,
#  4: 8907,
#  5: 8908,
#  6: 8909,
#  7: 8910,
#  8: 8911,
#  9: 8912,
#  10: 8913,
#  11: 8914,
#  12: 8915,
#  13: 8916,
#  14: 8917,
#  15: 8918,
#  16: 8919,
#  17: 8920,
#  18: 8921,
#  19: 8922,
#  20: 8923,
#  21: 8924,
#  22: 8925,
#  23: 8926,
#  24: 8927,
#  25: 8928,
#  26: 8929,
#  27: 8930,
#  28: 8931,
#  29: 8932,
#  30: 8933,
#  31: 8934,
#  32: 8935,
#  33: 8936,
#  34: 8937,
#  35: 8938,
#  36: 8939,
#  37: 8940,
#  38: 8941,
#  39: 8942,
#  40: 8943,
#  41: 8944,
#  42: 8945,
#  43: 8946,
#  44: 8947,
#  45: 8948,
#  46: 8949,
#  47: 8950,
#  48: 8951,
#  49: 8952,
#  50: 8953,
#  51: 8954,
#  52: 8955,
#  53: 8956,
#  54: 8957,
#  55: 8958,
#  56: 8959,
#  57: 8960,
#  58: 8961,
#  59: 8962,
#  60: 8963,
#  61: 8964,
#  62: 8965,
#  63: 8966,
#  64: 8967,
#  65: 8968,
#  66: 8969,
#  67: 8970,
#  68: 8971,
#  69: 8972,
#  70: 8973,
#  71: 8974,
#  72: 8975,
#  73: 8976,
#  74: 8977,
#  75: 8978,
#  76: 8979,
# ...

# %%
df.drop(['Unnamed: 0'], axis=1)
# Out:
#         Speed_MPH    ATP  BP_Hg       JF     FF  Src_Temperature  \
# 0        7.333333  19.60   28.9  1.43925  25.85            84.04
# 1        5.000000  18.70   28.9  1.43925  25.85            84.04
# 2       18.000000  16.90   28.9  1.02432  33.06            84.04
# 3       20.500000  16.90   28.9  1.70738  24.79            84.04
# 4        1.000000  17.30   28.9  1.43925  25.85            84.04
# ...           ...    ...    ...      ...    ...              ...
# 244709   6.666667  15.60   29.5  0.00000  45.61            93.45
# 244710   8.500000  20.15   29.5  0.00000  45.61            93.45
# 244711  11.000000  21.90   29.5  0.00000  45.61            93.45
# 244712  14.000000  23.80   29.5  0.00000  45.61            93.45
# 244713  17.000000  25.50   29.5  0.00000  45.61            93.45
#
#         Src_Pressure  Src_WindSpeed Src_Weather_Info      NR_HR  ...  \
# 0             1014.0          10.36                1  18.207775  ...
# ...
